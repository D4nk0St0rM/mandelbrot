# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# !pip install periodic
# Out:
# Collecting periodic
#   Downloading https://files.pythonhosted.org/packages/85/af/728c1f8842f615625b81d0a3ab8ac548f0a430f4826647490903262498fb/periodic-2.1.1.tar.gz
# Collecting SQLAlchemy==0.7.7
#   Downloading https://files.pythonhosted.org/packages/3d/7e/aab0cdb7f5101f0601a827638b609f40491d457ee0ca500707efd59ced48/SQLAlchemy-0.7.7.tar.gz (2.6MB)
#      |████████████████████████████████| 2.6MB 4.1MB/s
# Building wheels for collected packages: periodic, SQLAlchemy
#   Building wheel for periodic (setup.py) ... done
#   Created wheel for periodic: filename=periodic-2.1.1-cp27-none-any.whl size=7870 sha256=f778cc767d463c3c335e127edbed2d3dbed9d6366c83178a40621e962cf55459
#   Stored in directory: /root/.cache/pip/wheels/d6/78/5d/c34f7823af83fb91e3ab0d2f5beddb1d250306641b775365a0
#   Building wheel for SQLAlchemy (setup.py) ... done
#   Created wheel for SQLAlchemy: filename=SQLAlchemy-0.7.7-cp27-cp27mu-linux_x86_64.whl size=719275 sha256=1e16f61c753c0e77aa07caa7ac8e4f7fc7f717f4c0340d4ead7f9fcee8c6a8cf
#   Stored in directory: /root/.cache/pip/wheels/14/d2/3f/c0a6a4e358008563ddc2206cf4ce0d82a27cd9d4759a7051be
# Successfully built periodic SQLAlchemy
# Installing collected packages: SQLAlchemy, periodic
#   Found existing installation: SQLAlchemy 1.3.5
#     Uninstalling SQLAlchemy-1.3.5:
#       Successfully uninstalled SQLAlchemy-1.3.5
# Successfully installed SQLAlchemy-0.7.7 periodic-2.1.1

# %% [markdown]
# Write a program that:
#
# *   calculates the frequency and wavelength of a photon emitted or absorbed when a hydrogen-like ion changes its quantum state
# *   requires the user to provide the atomic number of the ion and the principal quantum number of the initial and final states
# * tells the user whether the photon is emitted or absorbed.

# %%
# Calculate the energy and whether a photon is emitted or absorbed by user entry of initial and final states of an electron

#import libraries
import numpy as np
import periodic
from periodic.table import element # attributes symbol, name, mass, atomic, charge, type

# global variables
screenbreakstring = '_________________________________________________________'
ryd_constant=13.6 # Rydberg constant in eV
plnk_con_eV =4.1357e-15 # Plancks constant in eV
plnk_con_J =6.626e-34 # Plancks constant in J
reduce_plnk_con = plnk_con_J / ( 2 * np.pi)
ryd_constant=13.6 # Rydberg constant in eV
elec_chg_C =-1.602e-19 # Charge of an electron
c = 2.99792458e8 # Speed of Light
l_list = [] # Max range of l values list 
m_list = [] # Max range of m_l values list
spin = ['-1/2','1/2']


# welcome
print 'Calculate the energy and whether a photon is emitted or absorbed by user entry of initial and final states of an electron'

# user entry required for n variable
print screenbreakstring
print 'We need some input from you'
print screenbreakstring

while True:
  n_initial = int(input('Intial state -> What is the principle quantum number [between 1 and 10] :'))
  if n_initial <1 or n_initial > 10:
    print 'Initial n state out of range, try again: '
  else:
    break

while True:
  n_final = int(input('Final state -> What is the principle quantum number [between 1 and 10] :'))
  if n_final < 1 or n_final > 10:
    print 'Final n state out of range, try again: '
  else:
    break

while True:
  atom_num = int(input('Atomic number -> enter the atomic number of the ion [valid periodic table number] :'))
  if atom_num < 1 or atom_num > 118: # unable to validate against range via != ptble_rng - look into this!
    print 'Invalid atomic number, try again: '
  else:
    break

#calculate energy values
def e_val(n):
  e_val = - ryd_constant/(n*n)
  return e_val


def energy_total(initial_e,final_e):
  e_photon = final_e - initial_e  
  return e_photon
  
def wave_from_e(e):
  h = plnk_con_J
  lamda = abs((h * c) / convert_e(e))
  return lamda

def photon_freq(lam):
  pho_fre = abs(c / lam)
  return pho_fre

def convert_e(eJ): # convert energy from eV to J
  e_J = elec_chg_C * eJ
  return e_J

def emit_abso(e_v):
  if e_v < 0:
    in_out = 'absorbed'
  else:
    in_out = 'emitted'
  return in_out






## Final Outputs
e_ni = e_val(n_initial) # initial energy value
e_nf = e_val(n_final) # final energy value
photon_e = energy_total(e_ni,e_nf)
photon_lam = wave_from_e(photon_e)
photon_f = photon_freq(photon_lam)
loss_gain = emit_abso(photon_e)
#element_meta(atom_num)
ele = element(atom_num)
ele_name = ele.name
ele_sym = ele.symbol
ele_mass = ele.mass
k = 2 * np.pi / abs((plnk_con_J * c) / photon_e)
p = reduce_plnk_con / k 


print 'You entered the atomic number',atom_num,' and this is ',ele_sym,' being ',ele_name,' with atomic mass ',ele_mass
print 'The energy value of your intitial n state ', n_initial,': ', e_ni,'eV'
print 'The energy value of your final n state ',n_final,': ', e_nf,'eV'
print 'The wave number being ',k,' with momentum ', p
print 'The photon engery of moving from intial to final :', photon_e, 'eV, this photon being ',loss_gain
print 'The wavelength of this photon energy value being :', photon_lam, 'm'
print 'The frequency of this photon energy value being :', photon_f, 'Hz'
print 'Here are all the possible quantum states at your final value of n:'
print screenbreakstring
print 'n =',n_final,'|  l = 0  | m_l =  0 | m_s =  -1/2 |'
print 'n =',n_final,'|  l = 0  | m_l =  0 | m_s =   1/2 |'

#Max Range of l
l_list = range(0,int(n_final))
l_total = len(l_list)

for l in l_list:
  m_list = range(-l,l)
  m_total = len(m_list)
  for m in m_list:
    if int(m) < 0:
      print 'n =',n_final,'|  l =',l,' | m_l =',m,'| m_s =',spin[0],' |'
      print 'n =',n_final,'|  l =',l,' | m_l =',m,'| m_s = ',spin[1],' |'
    else:
      print 'n =',n_final,'|  l =',l,' | m_l = ',m,'| m_s =',spin[0],' |'
      print 'n =',n_final,'|  l =',l,' | m_l = ',m,'| m_s =',spin[1],' |'

#Total quantum states 
qstate = (l_total * m_total)+2

#End
print screenbreakstring
print 'there are a total of ',qstate,' quantum states for n = ',n_final
print screenbreakstring
print 'Heres the periodic table just for reference:'
print periodic.table
print screenbreakstring
print 'bye!'
print screenbreakstring
print screenbreakstring
print screenbreakstring
# Out:
# Calculate the energy and whether a photon is emitted or absorbed by user entry of initial and final states of an electron
# _________________________________________________________
# We need some input from you
# _________________________________________________________
# Intial state -> What is the principle quantum number [between 1 and 10] :6
# Final state -> What is the principle quantum number [between 1 and 10] :8
# Atomic number -> enter the atomic number of the ion [valid periodic table number] :8
# You entered the atomic number 8  and this is  O  being  Oxygen  with atomic mass  15.9994
# The energy value of your intitial n state  6 :  -0.377777777778 eV
# The energy value of your final n state  8 :  -0.2125 eV
# The wave number being  5.22783893442e+24  with momentum  2.01720188046e-59
# The photon engery of moving from intial to final : 0.165277777778 eV, this photon being  emitted
# The wavelength of this photon energy value being : 7.50231263038e-06 m
# The frequency of this photon energy value being : 3.99600060368e+13 Hz
# Here are all the possible quantum states at your final value of n:
# _________________________________________________________
# n = 8 |  l = 0  | m_l =  0 | m_s =  -1/2 |
# n = 8 |  l = 0  | m_l =  0 | m_s =   1/2 |
# n = 8 |  l = 1  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 1  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 1  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 1  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 2  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 2  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 2  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 2  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 2  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 2  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 2  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 2  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 3  | m_l = -3 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l = -3 | m_s =  1/2  |
# n = 8 |  l = 3  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 3  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 3  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 3  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 3  | m_l =  2 | m_s = -1/2  |
# n = 8 |  l = 3  | m_l =  2 | m_s = 1/2  |
# n = 8 |  l = 4  | m_l = -4 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l = -4 | m_s =  1/2  |
# n = 8 |  l = 4  | m_l = -3 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l = -3 | m_s =  1/2  |
# n = 8 |  l = 4  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 4  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 4  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 4  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 4  | m_l =  2 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l =  2 | m_s = 1/2  |
# n = 8 |  l = 4  | m_l =  3 | m_s = -1/2  |
# n = 8 |  l = 4  | m_l =  3 | m_s = 1/2  |
# n = 8 |  l = 5  | m_l = -5 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l = -5 | m_s =  1/2  |
# n = 8 |  l = 5  | m_l = -4 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l = -4 | m_s =  1/2  |
# n = 8 |  l = 5  | m_l = -3 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l = -3 | m_s =  1/2  |
# n = 8 |  l = 5  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 5  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 5  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 5  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 5  | m_l =  2 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l =  2 | m_s = 1/2  |
# n = 8 |  l = 5  | m_l =  3 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l =  3 | m_s = 1/2  |
# n = 8 |  l = 5  | m_l =  4 | m_s = -1/2  |
# n = 8 |  l = 5  | m_l =  4 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l = -6 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -6 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l = -5 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -5 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l = -4 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -4 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l = -3 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -3 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 6  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l =  2 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  2 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l =  3 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  3 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l =  4 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  4 | m_s = 1/2  |
# n = 8 |  l = 6  | m_l =  5 | m_s = -1/2  |
# n = 8 |  l = 6  | m_l =  5 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l = -7 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -7 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -6 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -6 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -5 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -5 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -4 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -4 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -3 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -3 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -2 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -2 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l = -1 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l = -1 | m_s =  1/2  |
# n = 8 |  l = 7  | m_l =  0 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  0 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  1 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  1 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  2 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  2 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  3 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  3 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  4 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  4 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  5 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  5 | m_s = 1/2  |
# n = 8 |  l = 7  | m_l =  6 | m_s = -1/2  |
# n = 8 |  l = 7  | m_l =  6 | m_s = 1/2  |
# _________________________________________________________
# there are a total of  114  quantum states for n =  8
# _________________________________________________________
# Heres the periodic table just for reference:
#   -----                                                               -----
# 1 | H |                                                               |He |
#   |---+----                                       --------------------+---|
# 2 |Li |Be |                                       | B | C | N | O | F |Ne |
#   |---+---|                                       |---+---+---+---+---+---|
# 3 |Na |Mg |3B  4B  5B  6B  7B |    8B     |1B  2B |Al |Si | P | S |Cl |Ar |
#   |---+---+---------------------------------------+---+---+---+---+---+---|
# 4 | K |Ca |Sc |Ti | V |Cr |Mn |Fe |Co |Ni |Cu |Zn |Ga |Ge |As |Se |Br |Kr |
#   |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
# 5 |Rb |Sr | Y |Zr |Nb |Mo |Tc |Ru |Rh |Pd |Ag |Cd |In |Sn |Sb |Te | I |Xe |
#   |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
# 6 |Cs |Ba |LAN|Hf |Ta | W |Re |Os |Ir |Pt |Au |Hg |Tl |Pb |Bi |Po |At |Rn |
#   |---+---+---+------------------------------------------------------------
# 7 |Fr |Ra |ACT|
#   -------------
#               -------------------------------------------------------------
#    Lanthanide |La |Ce |Pr |Nd |Pm |Sm |Eu |Gd |Tb |Dy |Ho |Er |Tm |Yb |Lu |
#               |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
#    Actinide   |Ac |Th |Pa | U |Np |Pu |Am |Cm |Bk |Cf |Es |Fm |Md |No |Lw |
#               -------------------------------------------------------------
# _________________________________________________________
# bye!
# _________________________________________________________
# _________________________________________________________
# _________________________________________________________

# %% [markdown]
# Write a program that determines the possible values of the orbital quantum number l for a given value of the principal quantum number n and then produces a list of these numbers

# %%
#Determine quantum state numbers for all orbitals from user enterred input quantum number n

#set variables
l_list = [] # Max range of l values list 
m_list = [] # Max range of m_l values list
spin = ['-1/2','1/2"]
state = 1 # to increment on states and return total number of states based on range n=1 to n=user_entry
screenbreakstring = "________________________________________________________________________________" #tidy up output on juypter notebook / colab.google.com

# user entry required for n variable
print screenbreakstring
print "This will list all quantum state numbers from orbital shell 1 to the shell you enter:"
print screenbreakstring
n = int(input("Please enter the n orbital number: "))

# If entry is 0 keep asking
# Think about a validation for range and text here

while n <1:
  print screenbreakstring
  print "dont be silly, think about it"
  n = int(input("Please enter the n orbital number: "))

# Max Range of l
l_list = range(0,int(n))
#print l_list
l_total = len(l_list)

# print value of l = 0 ocurring as per all valid quantum states
print screenbreakstring
print "Quantum state number for your entered value of n||>|>   n =",n,"|  l = 0  | m_l =  0 | m_s =  -1/2 |"
print "Quantum state number for your entered value of n||>|>   n =",n,"|  l = 0  | m_l =  0 | m_s =   1/2 |"

for l in l_list:
  m_list = range(-l,l)
  m_total = len(m_list)
  for m in m_list:
    if int(m) < 0:
      print "Quantum state number for your entered value of n||>|>   n =",n,"|  l =",l," | m_l =",m,"| m_s =",spin[0]," |"
      print "Quantum state number for your entered value of n||>|>   n =",n,"|  l =",l," | m_l =",m,"| m_s = ",spin[1]," |"
    else:
      print "Quantum state number for your entered value of n||>|>   n =",n,"|  l =",l," | m_l = ",m,"| m_s =",spin[0]," |"
      print "Quantum state number for your entered value of n||>|>   n =",n,"|  l =",l," | m_l = ",m,"| m_s =",spin[1]," |"

#Total quantum states 
qstate = (l_total * m_total)+2

#End the day 

print screenbreakstring
print "there are a total of ",qstate," quantum states for n = ",n
print screenbreakstring
print "bye......"
# Out:
# ________________________________________________________________________________
# This will list all quantum state numbers from orbital shell 1 to the shell you enter:
# ________________________________________________________________________________
# Please enter the n orbital number: 4
# ________________________________________________________________________________
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 0  | m_l =  0 | m_s =  -1/2 |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 0  | m_l =  0 | m_s =   1/2 |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 1  | m_l = -1 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 1  | m_l = -1 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 1  | m_l =  0 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 1  | m_l =  0 | m_s = 1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l = -2 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l = -2 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l = -1 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l = -1 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l =  0 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l =  0 | m_s = 1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l =  1 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 2  | m_l =  1 | m_s = 1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -3 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -3 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -2 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -2 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -1 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l = -1 | m_s =  1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  0 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  0 | m_s = 1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  1 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  1 | m_s = 1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  2 | m_s = -1/2  |
# Quantum state number for your entered value of n||>|>   n = 4 |  l = 3  | m_l =  2 | m_s = 1/2  |
# ________________________________________________________________________________
# there are a total of  26  quantum states for n =  4
# ________________________________________________________________________________
# bye......

# %% [markdown]
# In Section 1.1  you modified a short program to calculate the energy of a state of a hydrogen-like ion.
#
# Later on, you will be asked to write a program that calculates the energy difference between two states. While writing this program, it would be very useful if there was a function available that could calculate the energy of a state. The program below does this for hydrogen.

# %%
# This program calculates the energy (in eV) of the state of a 
# hydrogen  atom with  principal quantum number n

# We define the function that calculates the energy of a state 
# of the hydrogen atom with principal quantum number n

def energy(n):
  # Rydberg constant in eV
  ryd_constant=13.6
  ener = - ryd_constant/(n*n)
  return ener

# ask user for principal quantum number n
n = int(input("What is the principal quantum number?"))

print "Energy of the hydrogen state:", energy(n), "eV"
# Out:
# What is the principal quantum number?3
# Energy of the hydrogen state: -1.51111111111 eV

# %% [markdown]
# Write a program that uses a function to calculate the frequency of a photon emitted or absorbed when a hydrogen atom changes its quantum state from n =4  to n =1 . Use  4.1357 x 10^-15 ev for the value of Planck’s constant (h)
#
# Noting the following
#
# E_photon = E_final - E_initial
#
# E_Photon = lamda (wavelength) x plancks constant (h)
#
#
# frequency (f) = c / lamda
#
# Calc energy when n = 4
#
# Calc engery when n =1

# %%
#Question: What is the frequency of a photon emitted or absorbed when a hydrogen atom changes its quantum state from n =4 to n = 1

# frenquency = c / lamda
# frequency = E/h
# E in J
# E for hydrogen atom at n: E = -13.6 eV / n^2
# DO1 - Calc E for each value of n
#1 - Convert Plancks constant to J

#define constants globally

ryd_constant=13.6 # Rydberg constant in eV
plnk_con_eV =4.1357e-15 # Plancks constant in eV
plnk_con_J =6.626e-34 # Plancks constant in J
ryd_constant=13.6 # Rydberg constant in eV
elec_chg_C =-1.602e-19 # Charge of an electron
c = 2.99792458e8 # Speed of Light

in_e = input("Enter initial n value: ")
fin_e = input("Enter final n value: ")

def energy_n_level(n):
  energy_n = ryd_constant/(n**2)
  return energy_n

e_nf = energy_n_level(fin_e)
e_ni = energy_n_level(in_e)

def energy_total(initial_e,final_e):
  initial_e = e_ni
  final_e = e_nf
  e_photon = initial_e - final_e  
  return e_photon

e_ph = energy_total(e_ni,e_nf)


def wave_from_e(e):
  h = plnk_con_eV
  e = e_ph
  lamda = (e / h)
  return lamda

wv_lam = wave_from_e(e_ph)

def photon_freq(lamda):
  pho_fre = c / lamda
  return pho_fre

freq = (wv_lam)

print "Where n = ",fin_e,", then E=",e_nf,"eV"
print "Where n = ",in_e,", then E=",e_ni,"eV"
print "Energy of electron moving from n=",in_e," to n=",fin_e," :",e_pro,"eV"
print "Wavelength of energy gain/loss from the move from n =", in_e," to n=",fin_e," is ",wv_lam, "m"
print "Frequencey of photon from the energy gain/loss from n =", in_e," to n=",fin_e," is ",freq,"Hz"
# Out:
# Enter initial n value: 4
# Enter final n value: 1
# Where n =  1 , then E= 13.6 eV
# Where n =  4 , then E= 0.85 eV
# Energy of electron moving from n= 4  to n= 1  : 2.55 eV
# Wavelength of energy gain/loss from the move from n = 4  to n= 1  is  -3.0829122035e+15 m
# Frequencey of photon from the energy gain/loss from n = 4  to n= 1  is  -3.0829122035e+15 Hz

# %% [markdown]
# Write a program that:
#
# calculates the frequency and wavelength of a photon emitted or absorbed when a hydrogen-like ion changes its quantum state
#
# requires the user to provide the atomic number of the ion and the principal quantum number of the initial and final states
#
# tells the user whether the photon is emitted or absorbed.
#
#
# Hint: you may want to write down the algorithm first. Also, you can adapt or make use of the functions you have already coded.
